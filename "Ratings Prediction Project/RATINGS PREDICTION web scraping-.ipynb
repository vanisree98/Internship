# %% [markdown]
# # RATINGS PREDICTION web scraping

# %% [markdown]
# In this section you need to scrape the reviews of different laptops, Phones, Headphones, smartwatches,
#
# Professional Cameras, Printers, clock, Home theater, Iron box,AC,refrigerator from thet e-commerce
#
# websites.

# %%
#Let's install the selenium Library
! pip install selenium

# %%
#lets noe import all the required libraries 
import selenium
from bs4 import BeautifulSoup
import pandas as pd 
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import requests
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import time

# %%
#Lets first connect to the web drive

driver= webdriver.Chrome(r'C:\Users\Hi\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver=webdriver.Chrome("chromedriver.exe")
time.sleep(2)

# %% [markdown]
# ### scrape the reviews of different brand of Phones

# %%
driver.get('https://www.flipkart.com/samsung-galaxy-f13-waterfall-blue-64-gb/p/itm583ef432b2b0c?pid=MOBGENJWBPFYJSFT&lid=LSTMOBGENJWBPFYJSFT1ZY7B0&marketplace=FLIPKART&q=samsung+galaxy+f13&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_1&otracker=AS_QueryStore_OrganicAutoSuggest_2_14_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_2_14_na_na_ps&fm=search-autosuggest&iid=f8b56155-b71c-4a4a-b172-b46c8427f54a.MOBGENJWBPFYJSFT.SEARCH&ppt=sp&ppn=sp&ssid=g4xtf2vf9c0000001659437591389&qH=ae67bd136f0a18a1')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,44):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
len(Rating)
# Out:
# 440

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:440], 
   'Review Summary':Review_summary[:440], 
   'Full Review':Full_review[:440],
   'Review_date':Date[:440]
}
phone2 = pd.DataFrame(data=dictionnary)
pr = ['Phone']*440

phone2.insert(0,'Product',pr)
phone2
# Out:
#     Product Rating         Review Summary  \
# 0     Phone      3                   Fair
# 1     Phone      4           Nice product
# 2     Phone      5  Mind-blowing purchase
# 3     Phone      5      Terrific purchase
# 4     Phone      5  Mind-blowing purchase
# ..      ...    ...                    ...
# 435   Phone      5               Terrific
# 436   Phone      5                Awesome
# 437   Phone      3         Decent product
# 438   Phone      5      Terrific purchase
# 439   Phone      4              Very Good
#
#                                            Full Review  Review_date
# 0    This mobile is purely for normal use, I don't ...  1 month ago
# 1    I am using this Phone since last 7 days , Feel...  18 days ago
# 2    🌟Its a great day to day usage phone🌟\nBest bud...  1 month ago
# 3    Very good budget branded Phone.\nNot suitable ...  10 days ago
# 4                                     Vale for money 💰  14 days ago
# ...

# %%
p = ['₹11,999']*440
d = ['SAMSUNG Galaxy F13']*440

phone2.insert(1,'Price',p)
phone2.insert(1, 'Brand_name', d)

phone2
# Out:
#     Product          Brand_name    Price Rating         Review Summary  \
# 0     Phone  SAMSUNG Galaxy F13  ₹11,999      3                   Fair
# 1     Phone  SAMSUNG Galaxy F13  ₹11,999      4           Nice product
# 2     Phone  SAMSUNG Galaxy F13  ₹11,999      5  Mind-blowing purchase
# 3     Phone  SAMSUNG Galaxy F13  ₹11,999      5      Terrific purchase
# 4     Phone  SAMSUNG Galaxy F13  ₹11,999      5  Mind-blowing purchase
# ..      ...                 ...      ...    ...                    ...
# 435   Phone  SAMSUNG Galaxy F13  ₹11,999      5               Terrific
# 436   Phone  SAMSUNG Galaxy F13  ₹11,999      5                Awesome
# 437   Phone  SAMSUNG Galaxy F13  ₹11,999      3         Decent product
# 438   Phone  SAMSUNG Galaxy F13  ₹11,999      5      Terrific purchase
# 439   Phone  SAMSUNG Galaxy F13  ₹11,999      4              Very Good
#
#                                            Full Review  Review_date
# ...

# %%
driver.get('https://www.flipkart.com/oppo-f11-pro-aurora-green-64-gb/p/itmfe6k2gurv2a3p?pid=MOBFE6KFGD6YT27Z&lid=LSTMOBFE6KFGD6YT27ZWDYUV3&marketplace=FLIPKART&q=oppo+f21+pro&store=tyy%2F4io&srno=s_1_5&otracker=AS_QueryStore_OrganicAutoSuggest_2_3_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_2_3_na_na_ps&fm=search-autosuggest&iid=df1985e0-6c26-4310-ae2f-87a92a4fb911.MOBFE6KFGD6YT27Z.SEARCH&ppt=sp&ppn=sp&ssid=4ynhsm5ykw0000001659436196584&qH=0609dc5a34e0f8ca')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,155):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
len(Rating)
# Out:
# 1570

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:1570], 
   'Review Summary':Review_summary[:1570], 
   'Full Review':Full_review[:1570],
   'Review_date':Date[:1570]
}
phone3 = pd.DataFrame(data=dictionnary)
pr = ['Phone']*1570

phone3.insert(0,'Product',pr)
phone3
# Out:
#      Product Rating       Review Summary  \
# 0      Phone      5  Best in the market!
# 1      Phone      5     Perfect product!
# 2      Phone      5            Wonderful
# 3      Phone      5       Simply awesome
# 4      Phone      5             Terrific
# ...      ...    ...                  ...
# 1565   Phone      5            Just wow!
# 1566   Phone      5  Best in the market!
# 1567   Phone      5    Worth every penny
# 1568   Phone      2  Could be way better
# 1569   Phone      4          Pretty good
#
#                                             Full Review Review_date
# 0     Everything is so elegant whether it be the cam...   Apr, 2019
# 1     Awesome purchase.. ThanQ flipkart the day one ...   Mar, 2020
# 2     Gentle Mobile Battery backup is good .\ncamera...   Jul, 2019
# 3     MIND BLOWING CAMERA PHONE , NOW GO AND BUY IT ...   Oct, 2019
# 4     I am oppo fan lover. camera quality is very go...   Jul, 2019
# ...

# %%
p = ['₹28,990']*1570
d = ['OPPO F11 Pro']*1570
phone3.insert(1,'Price',p)
phone3.insert(1, 'Brand_name', d)


phone3
# Out:
#      Product    Brand_name    Price Rating       Review Summary  \
# 0      Phone  OPPO F11 Pro  ₹28,990      5  Best in the market!
# 1      Phone  OPPO F11 Pro  ₹28,990      5     Perfect product!
# 2      Phone  OPPO F11 Pro  ₹28,990      5            Wonderful
# 3      Phone  OPPO F11 Pro  ₹28,990      5       Simply awesome
# 4      Phone  OPPO F11 Pro  ₹28,990      5             Terrific
# ...      ...           ...      ...    ...                  ...
# 1565   Phone  OPPO F11 Pro  ₹28,990      5            Just wow!
# 1566   Phone  OPPO F11 Pro  ₹28,990      5  Best in the market!
# 1567   Phone  OPPO F11 Pro  ₹28,990      5    Worth every penny
# 1568   Phone  OPPO F11 Pro  ₹28,990      2  Could be way better
# 1569   Phone  OPPO F11 Pro  ₹28,990      4          Pretty good
#
#                                             Full Review Review_date
# 0     Everything is so elegant whether it be the cam...   Apr, 2019
# ...

# %% [markdown]
# ### scrape the reviews of different brand of headset

# %%
driver.get('https://www.flipkart.com/boat-bassheads-103-blue-wired-headset/p/itma6533ab620ab5?pid=ACCFGYHHKJ94GN6A&lid=LSTACCFGYHHKJ94GN6AGRUYOH&marketplace=FLIPKART&q=headphones&store=0pm%2Ffcn&srno=s_1_2&otracker=search&otracker1=search&fm=Search&iid=en_rQtnTb3AfLUlpR1bYvS%2BtDgU7vQfJIPVq3iXff1Sy11AmedA7DQ7GF5AIlbTDUJUl3SDoluXeLVo1c5gw4yLFQ%3D%3D&ppt=sp&ppn=sp&ssid=lfzzna4mkw0000001659430205652&qH=edd443896ef5dbfc')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,150):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
len(Rating)
# Out:
# 1344

# %%
len(Review_summary)

# %%
#Store the data in a dataframe.    
dictionnary = {
   
   'Rating': Rating[:1344], 
   'Review Summary':Review_summary[:1344], 
   'Full Review':Full_review[:1344],
   'Review_date':Date[:1344]
}
head_set1 = pd.DataFrame(data=dictionnary) 
pr = ['Headset']*1344

head_set1.insert(0,'Product',pr)
head_set1
# Out:
#       Product Rating         Review Summary  \
# 0     Headset      5  Mind-blowing purchase
# 1     Headset      4              Wonderful
# 2     Headset      4            Really Nice
# 3     Headset      5              Brilliant
# 4     Headset      5      Terrific purchase
# ...       ...    ...                    ...
# 1339  Headset      1      Absolute rubbish!
# 1340  Headset      4            Really Nice
# 1341  Headset      5         Classy product
# 1342  Headset      4              Wonderful
# 1343  Headset      5    Best in the market!
#
#                                             Full Review  Review_date
# 0     The product comes with a warranty card for one...    May, 2020
# 1     Great product in the price range. Decent sound...    Feb, 2020
# 2     Awesome product.. i received it earlier than t...    May, 2020
# 3     Super product ..Again I am writing this review...    May, 2020
# 4     very Good Product with enough bass..and nice d...    Nov, 2019
# ...

# %%
p = ['₹399']*1344
d = ['boAt Basshead Headset']*1344

head_set1.insert(1,'Price',p)
head_set1.insert(1, 'Brand_name', d)

head_set1
# Out:
#       Product             Brand_name Price Rating         Review Summary  \
# 0     Headset  boAt Basshead Headset  ₹399      5  Mind-blowing purchase
# 1     Headset  boAt Basshead Headset  ₹399      4              Wonderful
# 2     Headset  boAt Basshead Headset  ₹399      4            Really Nice
# 3     Headset  boAt Basshead Headset  ₹399      5              Brilliant
# 4     Headset  boAt Basshead Headset  ₹399      5      Terrific purchase
# ...       ...                    ...   ...    ...                    ...
# 1339  Headset  boAt Basshead Headset  ₹399      1      Absolute rubbish!
# 1340  Headset  boAt Basshead Headset  ₹399      4            Really Nice
# 1341  Headset  boAt Basshead Headset  ₹399      5         Classy product
# 1342  Headset  boAt Basshead Headset  ₹399      4              Wonderful
# 1343  Headset  boAt Basshead Headset  ₹399      5    Best in the market!
#
#                                             Full Review  Review_date
# ...

# %%
driver.get('https://www.flipkart.com/oneplus-bullets-wireless-z2-fast-charge-30-hrs-battery-life-earphones-mic-bluetooth-headset/product-reviews/itm1b9cd98911a2a?pid=ACCGC4GN5SQR7ZCZ&lid=LSTACCGC4GN5SQR7ZCZQKBRXO&marketplace=FLIPKART')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,100):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
len(Rating)
# Out:
# 1150

# %%
#Store the data in a dataframe.    
dictionnary = {
   
   'Rating': Rating[:1150], 
   'Review Summary':Review_summary[:1150], 
   'Full Review':Full_review[:1150],
   'Review_date':Date[:1150]
}
head_set2= pd.DataFrame(data=dictionnary) 
pr = ['Headset']*1150

head_set2.insert(0,'Product',pr)
head_set2
# Out:
#       Product Rating         Review Summary  \
# 0     Headset      4           Nice product
# 1     Headset      5         Simply awesome
# 2     Headset      5         Simply awesome
# 3     Headset      5  Mind-blowing purchase
# 4     Headset      5         Classy product
# ...       ...    ...                    ...
# 1145  Headset      3                   Fair
# 1146  Headset      1        Useless product
# 1147  Headset      5              Must buy!
# 1148  Headset      4              Very Good
# 1149  Headset      1               Horrible
#
#                                             Full Review   Review_date
# 0     👉Sound quality is excellent, Bass is awesome, ...  3 months ago
# 1     Excellent product. Superb bass. Worth for mone...  3 months ago
# 2     Superb product actually I won’t prefer wireles...  3 months ago
# 3     This is worth every penny you spend. I doesn't...  3 months ago
# 4     Wireless Bullets are first impressions are imp...  3 months ago
# ...

# %%
p = ['₹1,799']*1150
d = ['OnePlus Bullets Wireless Bluetooth Headset']*1150

head_set2.insert(1,'Price',p)
head_set2.insert(1, 'Brand_name', d)

head_set2
# Out:
#       Product                                  Brand_name   Price Rating  \
# 0     Headset  OnePlus Bullets Wireless Bluetooth Headset  ₹1,799      4
# 1     Headset  OnePlus Bullets Wireless Bluetooth Headset  ₹1,799      5
# 2     Headset  OnePlus Bullets Wireless Bluetooth Headset  ₹1,799      5
# 3     Headset  OnePlus Bullets Wireless Bluetooth Headset  ₹1,799      5
# 4     Headset  OnePlus Bullets Wireless Bluetooth Headset  ₹1,799      5
# ...       ...                                         ...     ...    ...
# 1145  Headset  OnePlus Bullets Wireless Bluetooth Headset  ₹1,799      3
# 1146  Headset  OnePlus Bullets Wireless Bluetooth Headset  ₹1,799      1
# 1147  Headset  OnePlus Bullets Wireless Bluetooth Headset  ₹1,799      5
# 1148  Headset  OnePlus Bullets Wireless Bluetooth Headset  ₹1,799      4
# 1149  Headset  OnePlus Bullets Wireless Bluetooth Headset  ₹1,799      1
#
#              Review Summary  \
# 0              Nice product
# 1            Simply awesome
# ...

# %%
driver.get('https://www.flipkart.com/techfire-fire-500v2-neckband-hi-bass-wireless-bluetooth-headphone-headset/p/itme293721806e2c?pid=ACCG5EPZBRZDZFSZ&lid=LSTACCG5EPZBRZDZFSZY15YXG&marketplace=FLIPKART&q=headphones&store=0pm%2Ffcn%2F821%2Fa7x%2F2rv&srno=s_1_7&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&fm=search-autosuggest&iid=05c91e1b-19cc-49bf-b49e-dbc02f31931b.ACCG5EPZBRZDZFSZ.SEARCH&ppt=sp&ppn=sp&qH=edd443896ef5dbfc')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,100):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
#Store the data in a dataframe.    
dictionnary = {
   
   'Rating': Rating[:932], 
   'Review Summary':Review_summary[:932], 
   'Full Review':Full_review[:932],
   'Review_date':Date[:932]
}
head_set3 = pd.DataFrame(data=dictionnary) 
pr = ['Headset']*932

head_set3.insert(0,'Product',pr)
head_set3
# Out:
#      Product Rating        Review Summary  \
# 0    Headset      5     Worth every penny
# 1    Headset      5      Perfect product!
# 2    Headset      5   Best in the market!
# 3    Headset      5             Just wow!
# 4    Headset      5    Highly recommended
# ..       ...    ...                   ...
# 927  Headset      5             Fabulous!
# 928  Headset      1      Terrible product
# 929  Headset      5     Terrific purchase
# 930  Headset      4  Good quality product
# 931  Headset      3                  Good
#
#                                            Full Review   Review_date
# 0    Great thanks to techfire team\nThis price rang...  4 months ago
# 1    This product is soo good product, stylish prod...  4 months ago
# 2    What a terrific Neckband 😍😍 better than I expe...  2 months ago
# 3    I'm giving this review after 7days and it's wo...  3 months ago
# 4    Beautiful and very good product , bass sound i...  2 months ago
# ...

# %%
p = ['₹426']*932
d = ['TECHFIRE Fire Neckband  Bluetooth Headset']*932

head_set3.insert(1,'Price',p)
head_set3.insert(1, 'Brand_name', d)

head_set3
# Out:
#      Product                                 Brand_name Price Rating  \
# 0    Headset  TECHFIRE Fire Neckband  Bluetooth Headset  ₹426      5
# 1    Headset  TECHFIRE Fire Neckband  Bluetooth Headset  ₹426      5
# 2    Headset  TECHFIRE Fire Neckband  Bluetooth Headset  ₹426      5
# 3    Headset  TECHFIRE Fire Neckband  Bluetooth Headset  ₹426      5
# 4    Headset  TECHFIRE Fire Neckband  Bluetooth Headset  ₹426      5
# ..       ...                                        ...   ...    ...
# 927  Headset  TECHFIRE Fire Neckband  Bluetooth Headset  ₹426      5
# 928  Headset  TECHFIRE Fire Neckband  Bluetooth Headset  ₹426      1
# 929  Headset  TECHFIRE Fire Neckband  Bluetooth Headset  ₹426      5
# 930  Headset  TECHFIRE Fire Neckband  Bluetooth Headset  ₹426      4
# 931  Headset  TECHFIRE Fire Neckband  Bluetooth Headset  ₹426      3
#
#            Review Summary                                        Full Review  \
# ...

# %% [markdown]
# ### scrape the reviews of different brand of Laptop

# %%
driver.get('https://www.flipkart.com/hp-ryzen-3-dual-core-3250u-8-gb-256-gb-ssd-windows-11-home-15s-gy0501au-thin-light-laptop/p/itmcc3db7767aba4?pid=COMG6MVEA2PWVH3B&lid=LSTCOMG6MVEA2PWVH3BJ8QBY0&marketplace=FLIPKART&q=laptop&store=6bo%2Fb5g&srno=s_1_10&otracker=search&otracker1=search&fm=search-autosuggest&iid=516cb87b-a285-4a3d-9252-d774f10bdac5.COMG6MVEA2PWVH3B.SEARCH&ppt=pp&ppn=pp&ssid=qavzbj7a7k0000001659438090375&qH=312f91285e048e09')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,33):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:330], 
   'Review Summary':Review_summary[:330], 
   'Full Review':Full_review[:330],
   'Review_date':Date[:330]
                    
}
Laptop1 = pd.DataFrame(data=dictionnary)
pr = ['Laptop']*330

Laptop1.insert(0,'Product',pr)
Laptop1
# Out:
#     Product Rating     Review Summary  \
# 0    Laptop      4         Delightful
# 1    Laptop      5   Perfect product!
# 2    Laptop      5     Simply awesome
# 3    Laptop      5             Super!
# 4    Laptop      1          Worthless
# ..      ...    ...                ...
# 325  Laptop      5          Wonderful
# 326  Laptop      5          Wonderful
# 327  Laptop      4        Really Nice
# 328  Laptop      4       Nice product
# 329  Laptop      5  Terrific purchase
#
#                                            Full Review   Review_date
# 0    This is thing I want to be...It s worked suprb...  7 months ago
# 1    It's a very good choice in this price range .n...  6 months ago
# 2    I writing review for this product after same d...  7 months ago
# 3    Such a nice laptop. In my opinion it's the bes...  7 months ago
# 4    It's not good for any work , performance is ve...  6 months ago
# ..                                                 ...           ...
# ...

# %%
p = ['₹31,990']*330
d = ['HP Ryzen 3 Dual Core 3250U Laptop']*330

Laptop1 .insert(1,'Price',p)
Laptop1.insert(1, 'Brand_name', d)

Laptop1
# Out:
#     Product                         Brand_name    Price Rating  \
# 0    Laptop  HP Ryzen 3 Dual Core 3250U Laptop  ₹31,990      4
# 1    Laptop  HP Ryzen 3 Dual Core 3250U Laptop  ₹31,990      5
# 2    Laptop  HP Ryzen 3 Dual Core 3250U Laptop  ₹31,990      5
# 3    Laptop  HP Ryzen 3 Dual Core 3250U Laptop  ₹31,990      5
# 4    Laptop  HP Ryzen 3 Dual Core 3250U Laptop  ₹31,990      1
# ..      ...                                ...      ...    ...
# 325  Laptop  HP Ryzen 3 Dual Core 3250U Laptop  ₹31,990      5
# 326  Laptop  HP Ryzen 3 Dual Core 3250U Laptop  ₹31,990      5
# 327  Laptop  HP Ryzen 3 Dual Core 3250U Laptop  ₹31,990      4
# 328  Laptop  HP Ryzen 3 Dual Core 3250U Laptop  ₹31,990      4
# 329  Laptop  HP Ryzen 3 Dual Core 3250U Laptop  ₹31,990      5
#
#         Review Summary                                        Full Review  \
# 0           Delightful  This is thing I want to be...It s worked suprb...
# ...

# %%
driver.get('https://www.flipkart.com/asus-vivobook-15-2022-core-i3-10th-gen-8-gb-512-gb-ssd-windows-11-home-x515ja-bq322ws-thin-light-laptop/p/itm6bb4edeb57b75?pid=COMGB6DZBWCDEXXA&lid=LSTCOMGB6DZBWCDEXXAMHCEBC&marketplace=FLIPKART&q=laptop&store=6bo%2Fb5g&srno=s_1_14&otracker=search&otracker1=search&fm=search-autosuggest&iid=516cb87b-a285-4a3d-9252-d774f10bdac5.COMGB6DZBWCDEXXA.SEARCH&ppt=pp&ppn=pp&ssid=qavzbj7a7k0000001659438090375&qH=312f91285e048e09')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,25):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:250], 
   'Review Summary':Review_summary[:250], 
   'Full Review':Full_review[:250],
   'Review_date':Date[:250]
}
Laptop2 = pd.DataFrame(data=dictionnary)
pr = ['Laptop']*250

Laptop2.insert(0,'Product',pr)
Laptop2
# Out:
#     Product Rating     Review Summary  \
# 0    Laptop      4        Good choice
# 1    Laptop      5     Classy product
# 2    Laptop      2           Moderate
# 3    Laptop      4        Good choice
# 4    Laptop      4       Nice product
# ..      ...    ...                ...
# 245  Laptop      4        Really Nice
# 246  Laptop      5          Excellent
# 247  Laptop      4        Really Nice
# 248  Laptop      5  Terrific purchase
# 249  Laptop      3          Just okay
#
#                                            Full Review   Review_date
# 0    Day2\nPros\nDesign looks good\nPerformance til...  5 months ago
# 1    Very good for usage after 1 month it is good a...  6 months ago
# 2    If you can affort few thousands extra you can ...  6 months ago
# 3    Highly recommended for students and other prof...  6 months ago
# 4    Writing this after using Vivobook 15 for 3 day...   1 month ago
# ..                                                 ...           ...
# ...

# %%
p = ['₹32,990']*250
d = ['ASUS VivoBook 15 (2022) Core i3 10th Gen Laptop']*250

Laptop2.insert(1,'Price',p)
Laptop2.insert(1, 'Brand_name', d)

Laptop2
# Out:
#     Product                                       Brand_name    Price Rating  \
# 0    Laptop  ASUS VivoBook 15 (2022) Core i3 10th Gen Laptop  ₹32,990      4
# 1    Laptop  ASUS VivoBook 15 (2022) Core i3 10th Gen Laptop  ₹32,990      5
# 2    Laptop  ASUS VivoBook 15 (2022) Core i3 10th Gen Laptop  ₹32,990      2
# 3    Laptop  ASUS VivoBook 15 (2022) Core i3 10th Gen Laptop  ₹32,990      4
# 4    Laptop  ASUS VivoBook 15 (2022) Core i3 10th Gen Laptop  ₹32,990      4
# ..      ...                                              ...      ...    ...
# 245  Laptop  ASUS VivoBook 15 (2022) Core i3 10th Gen Laptop  ₹32,990      4
# 246  Laptop  ASUS VivoBook 15 (2022) Core i3 10th Gen Laptop  ₹32,990      5
# 247  Laptop  ASUS VivoBook 15 (2022) Core i3 10th Gen Laptop  ₹32,990      4
# 248  Laptop  ASUS VivoBook 15 (2022) Core i3 10th Gen Laptop  ₹32,990      5
# 249  Laptop  ASUS VivoBook 15 (2022) Core i3 10th Gen Laptop  ₹32,990      3
#
# ...

# %%
driver.get('https://www.flipkart.com/infinix-inbook-x1-core-i3-10th-gen-8-gb-256-gb-ssd-windows-11-home-xl11-thin-light-laptop/p/itmc853735b3bcae?pid=COMG8Z3HYTJZFF2Z&lid=LSTCOMG8Z3HYTJZFF2ZTYHG57&marketplace=FLIPKART&q=laptop&store=6bo%2Fb5g&srno=s_7_151&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&fm=search-autosuggest&iid=30371e4e-d0d5-41a5-aead-7b201f492d2b.COMG8Z3HYTJZFF2Z.SEARCH&ppt=sp&ppn=sp&ssid=pmv7unnu2o0000001659899514392&qH=312f91285e048e09')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,50):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:500], 
   'Review Summary':Review_summary[:500], 
   'Full Review':Full_review[:500],
   'Review_date':Date[:500]
}
Laptop3 = pd.DataFrame(data=dictionnary)
pr = ['Laptop']*500

Laptop3.insert(0,'Product',pr)
Laptop3
# Out:
#     Product Rating          Review Summary  \
# 0    Laptop      5     Best in the market!
# 1    Laptop      5        Perfect product!
# 2    Laptop      5          Classy product
# 3    Laptop      5     Best in the market!
# 4    Laptop      4               Very Good
# ..      ...    ...                     ...
# 495  Laptop      5               Brilliant
# 496  Laptop      5                  Super!
# 497  Laptop      2   Slightly disappointed
# 498  Laptop      1  Don't waste your money
# 499  Laptop      1  Don't waste your money
#
#                                            Full Review   Review_date
# 0    No other laptops can't beat this, at this pric...  7 months ago
# 1    First of all the design is superb. Its compact...  7 months ago
# 2    Just Brilliant ♥️, no match at 33k highly reco...  4 months ago
# 3    1.First Flipkart Love it ❤️ Very Fast Delivery...  7 months ago
# 4    The design and build quality seems premium. Th...  7 months ago
# ...

# %%
p = ['₹29,990']*500
d = ['Infinix INBook X1 Core i3 Laptop ']*500

Laptop3.insert(1,'Price',p)
Laptop3.insert(1, 'Brand_name', d)

Laptop3
# Out:
#     Product                         Brand_name    Price Rating  \
# 0    Laptop  Infinix INBook X1 Core i3 Laptop   ₹29,990      5
# 1    Laptop  Infinix INBook X1 Core i3 Laptop   ₹29,990      5
# 2    Laptop  Infinix INBook X1 Core i3 Laptop   ₹29,990      5
# 3    Laptop  Infinix INBook X1 Core i3 Laptop   ₹29,990      5
# 4    Laptop  Infinix INBook X1 Core i3 Laptop   ₹29,990      4
# ..      ...                                ...      ...    ...
# 495  Laptop  Infinix INBook X1 Core i3 Laptop   ₹29,990      5
# 496  Laptop  Infinix INBook X1 Core i3 Laptop   ₹29,990      5
# 497  Laptop  Infinix INBook X1 Core i3 Laptop   ₹29,990      2
# 498  Laptop  Infinix INBook X1 Core i3 Laptop   ₹29,990      1
# 499  Laptop  Infinix INBook X1 Core i3 Laptop   ₹29,990      1
#
#              Review Summary  \
# 0       Best in the market!
# 1          Perfect product!
# 2            Classy product
# 3       Best in the market!
# 4                 Very Good
# ..                      ...
# ...

# %% [markdown]
# ### scrape the reviews of different brand of smart watches

# %%
driver.get('https://www.flipkart.com/noise-colorfit-qube-spo2-smartwatch/p/itm2d9dc41a02202?pid=SMWG6RB5FX7RXWZ8&lid=LSTSMWG6RB5FX7RXWZ8MROVKI&marketplace=FLIPKART&q=smart+watches&store=ajy%2Fbuh&srno=s_1_4&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&fm=search-autosuggest&iid=a972fe5b-4f79-4bfd-a0f3-b1381b63364c.SMWG6RB5FX7RXWZ8.SEARCH&ppt=sp&ppn=sp&ssid=547hcd2dzk0000001659454820560&qH=87968ec020b2016b')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,130):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:1260], 
   'Review Summary':Review_summary[:1260], 
   'Full Review':Full_review[:1260],
   'Review_date':Date[:1260]
}
watch1 = pd.DataFrame(data=dictionnary)
pr = ['Watch']*1260

watch1.insert(0,'Product',pr)
watch1
# Out:
#      Product Rating         Review Summary  \
# 0      Watch      5              Fabulous!
# 1      Watch      4              Wonderful
# 2      Watch      4            Pretty good
# 3      Watch      3                   Good
# 4      Watch      3                   Fair
# ...      ...    ...                    ...
# 1255   Watch      4            Really Nice
# 1256   Watch      5     Highly recommended
# 1257   Watch      5                 Super!
# 1258   Watch      5               Terrific
# 1259   Watch      5  Mind-blowing purchase
#
#                                             Full Review    Review_date
# 0     This fit band is so good and so adjustable lik...   4 months ago
# 1     Good value for money everything is good only o...   9 months ago
# 2      Worth for money, Stylish + classy + good quality   9 months ago
# 3     Its my first experience on smart watch. I am j...  10 months ago
# 4     I was pretty much diassapointed with this prod...   9 months ago
# ...

# %%
p = ['₹1,499']*1260
d = ['Noise ColorFit Qube SpO2 Smartwatch']*1260

watch1.insert(1,'Price',p)
watch1.insert(1, 'Brand_name', d)
watch1
# Out:
#      Product                           Brand_name   Price Rating  \
# 0      Watch  Noise ColorFit Qube SpO2 Smartwatch  ₹1,499      5
# 1      Watch  Noise ColorFit Qube SpO2 Smartwatch  ₹1,499      4
# 2      Watch  Noise ColorFit Qube SpO2 Smartwatch  ₹1,499      4
# 3      Watch  Noise ColorFit Qube SpO2 Smartwatch  ₹1,499      3
# 4      Watch  Noise ColorFit Qube SpO2 Smartwatch  ₹1,499      3
# ...      ...                                  ...     ...    ...
# 1255   Watch  Noise ColorFit Qube SpO2 Smartwatch  ₹1,499      4
# 1256   Watch  Noise ColorFit Qube SpO2 Smartwatch  ₹1,499      5
# 1257   Watch  Noise ColorFit Qube SpO2 Smartwatch  ₹1,499      5
# 1258   Watch  Noise ColorFit Qube SpO2 Smartwatch  ₹1,499      5
# 1259   Watch  Noise ColorFit Qube SpO2 Smartwatch  ₹1,499      5
#
#              Review Summary  \
# 0                 Fabulous!
# 1                 Wonderful
# 2               Pretty good
# 3                      Good
# 4                      Fair
# ...

# %%
driver.get('https://www.flipkart.com/txor-storm-m5-35mm-screen-spo2-bp-monitor-smartwatch/p/itmdc249233324d3?pid=SMWFZR2PMHK6VSUM&lid=LSTSMWFZR2PMHK6VSUM8OFIMH&marketplace=FLIPKART&q=smart+watches&store=ajy%2Fbuh&srno=s_1_1&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&fm=search-autosuggest&iid=en_0w56y9RfFNYKTg11RoPm859ahw73W1wIrO%2BZiY2W28AATEWVrVJivqwZ%2FM7VdgLbOY248cRRk%2BkyYbNQeF8XZg%3D%3D&ppt=sp&ppn=sp&ssid=547hcd2dzk0000001659454820560&qH=87968ec020b2016b')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,50):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:1500], 
   'Review Summary':Review_summary[:1500], 
   'Full Review':Full_review[:1500],
   'Review_date':Date[:1500]
}
Watch2 = pd.DataFrame(data=dictionnary)
pr = ['Watch']*1500

Watch2.insert(0,'Product',pr)
Watch2
# Out:
#      Product Rating         Review Summary  \
# 0      Watch      5              Excellent
# 1      Watch      5  Mind-blowing purchase
# 2      Watch      5                Awesome
# 3      Watch      5                Awesome
# 4      Watch      5                 Super!
# ...      ...    ...                    ...
# 1495   Watch      5              Wonderful
# 1496   Watch      1               Horrible
# 1497   Watch      3                   Good
# 1498   Watch      4   Good quality product
# 1499   Watch      1              Very poor
#
#                                             Full Review    Review_date
# 0     Awesome Watch , More better than I ve expected...  11 months ago
# 1     Averagely Good for middle class families and D...   6 months ago
# 2     It's charging time Is not good If you will use...   7 months ago
# 3     This is tha amazing smartwatch I loved it beca...   5 months ago
# 4     Absolutely Delighted to have a watch like this...   4 months ago
# ...

# %%
p = ['₹629']*1500
d = ['TXOR Storm M5 Smartwatch ']*1500

Watch2.insert(1,'Price',p)
Watch2.insert(1, 'Brand_name', d)

Watch2
# Out:
#      Product                 Brand_name Price Rating         Review Summary  \
# 0      Watch  TXOR Storm M5 Smartwatch   ₹629      5              Excellent
# 1      Watch  TXOR Storm M5 Smartwatch   ₹629      5  Mind-blowing purchase
# 2      Watch  TXOR Storm M5 Smartwatch   ₹629      5                Awesome
# 3      Watch  TXOR Storm M5 Smartwatch   ₹629      5                Awesome
# 4      Watch  TXOR Storm M5 Smartwatch   ₹629      5                 Super!
# ...      ...                        ...   ...    ...                    ...
# 1495   Watch  TXOR Storm M5 Smartwatch   ₹629      5              Wonderful
# 1496   Watch  TXOR Storm M5 Smartwatch   ₹629      1               Horrible
# 1497   Watch  TXOR Storm M5 Smartwatch   ₹629      3                   Good
# 1498   Watch  TXOR Storm M5 Smartwatch   ₹629      4   Good quality product
# 1499   Watch  TXOR Storm M5 Smartwatch   ₹629      1              Very poor
#
# ...

# %%
# combining all the dataframes
vertical_stack1 = pd.concat([phone1,phone2,phone3,head_set1,head_set2,head_set3,Laptop1,Laptop2,Laptop3,watch1,watch2,watch3], axis=0)

# %%
# combining all the dataframes
df1 = pd.concat([phone2,phone3,head_set1,head_set2,head_set3,Laptop1,Laptop2,Laptop3,watch1], axis=0)

# %%
df1
# Out:
#      Product                           Brand_name    Price Rating  \
# 0      Phone                   SAMSUNG Galaxy F13  ₹11,999      3
# 1      Phone                   SAMSUNG Galaxy F13  ₹11,999      4
# 2      Phone                   SAMSUNG Galaxy F13  ₹11,999      5
# 3      Phone                   SAMSUNG Galaxy F13  ₹11,999      5
# 4      Phone                   SAMSUNG Galaxy F13  ₹11,999      5
# ...      ...                                  ...      ...    ...
# 1255   Watch  Noise ColorFit Qube SpO2 Smartwatch   ₹1,499      4
# 1256   Watch  Noise ColorFit Qube SpO2 Smartwatch   ₹1,499      5
# 1257   Watch  Noise ColorFit Qube SpO2 Smartwatch   ₹1,499      5
# 1258   Watch  Noise ColorFit Qube SpO2 Smartwatch   ₹1,499      5
# 1259   Watch  Noise ColorFit Qube SpO2 Smartwatch   ₹1,499      5
#
#              Review Summary  \
# 0                      Fair
# 1              Nice product
# 2     Mind-blowing purchase
# 3         Terrific purchase
# ...

# %%
df1.to_csv('RATING_products01_dt.csv')

# %% [markdown]
# ### scrape the reviews of different brand of Wall clock

# %%
driver.get('https://www.flipkart.com/ajanta-analog-26-5-cm-x-wall-clock/p/itmf63e3kkds6dva?pid=WCKF63E3GGG8FGGB&lid=LSTWCKF63E3GGG8FGGBBFLWNR&marketplace=FLIPKART&q=clock&store=arb%2Fkjw%2Fbm1&srno=s_1_6&otracker=AS_QueryStore_OrganicAutoSuggest_3_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_3_2_na_na_na&fm=search-autosuggest&iid=bc262b7e-b4c3-43e9-a216-983a8a164c73.WCKF63E3GGG8FGGB.SEARCH&ppt=sp&ppn=sp&ssid=d9qie90y8g0000001659455829191&qH=05531b19bb846b18')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,120):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:1200], 
   'Review Summary':Review_summary[:1200], 
   'Full Review':Full_review[:1200],
   'Review_date':Date[:1200]
}
clock1 = pd.DataFrame(data=dictionnary)
pr = ['Clock']*1200

clock1.insert(0,'Product',pr)
clock1
# Out:
#      Product Rating         Review Summary  \
# 0      Clock      5               Terrific
# 1      Clock      5               Terrific
# 2      Clock      5         Simply awesome
# 3      Clock      5                 Super!
# 4      Clock      5  Mind-blowing purchase
# ...      ...    ...                    ...
# 1195   Clock      4   Good quality product
# 1196   Clock      4   Good quality product
# 1197   Clock      5  Mind-blowing purchase
# 1198   Clock      5         Simply awesome
# 1199   Clock      5                Awesome
#
#                                             Full Review   Review_date
# 0     Thanks to everyone who made this beautiful wat...     Dec, 2020
# 1     excellent clock, best brand and battery given ...     Feb, 2019
# 2     Good and decent clock...\nVery good packaging ...     Mar, 2019
# 3     It's a very good wall clock... actually it's m...     Dec, 2019
# 4     Clock is good Packaging was great worth the mo...     Mar, 2020
# ...

# %%
p = ['₹264']*1200
d = ['AJANTA Analog Wall Clock']*1200

clock1.insert(1,'Price',p)
clock1.insert(1, 'Brand_name', d)

clock1
# Out:
#      Product                Brand_name Price Rating         Review Summary  \
# 0      Clock  AJANTA Analog Wall Clock  ₹264      5               Terrific
# 1      Clock  AJANTA Analog Wall Clock  ₹264      5               Terrific
# 2      Clock  AJANTA Analog Wall Clock  ₹264      5         Simply awesome
# 3      Clock  AJANTA Analog Wall Clock  ₹264      5                 Super!
# 4      Clock  AJANTA Analog Wall Clock  ₹264      5  Mind-blowing purchase
# ...      ...                       ...   ...    ...                    ...
# 1195   Clock  AJANTA Analog Wall Clock  ₹264      4   Good quality product
# 1196   Clock  AJANTA Analog Wall Clock  ₹264      4   Good quality product
# 1197   Clock  AJANTA Analog Wall Clock  ₹264      5  Mind-blowing purchase
# 1198   Clock  AJANTA Analog Wall Clock  ₹264      5         Simply awesome
# 1199   Clock  AJANTA Analog Wall Clock  ₹264      5                Awesome
#
# ...

# %%
driver.get('https://www.flipkart.com/kadio-analog-20-cm-x-wall-clock/p/itma4bede8bbe955?pid=WCKFHQHNZ6TNH3ZN&lid=LSTWCKFHQHNZ6TNH3ZNE7EDMI&marketplace=FLIPKART&q=clock&store=arb%2Fkjw%2Fbm1&spotlightTagId=BestsellerId_arb%2Fkjw%2Fbm1&srno=s_1_3&otracker=AS_QueryStore_OrganicAutoSuggest_3_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_3_2_na_na_na&fm=search-autosuggest&iid=bc262b7e-b4c3-43e9-a216-983a8a164c73.WCKFHQHNZ6TNH3ZN.SEARCH&ppt=sp&ppn=sp&ssid=d9qie90y8g0000001659455829191&qH=05531b19bb846b18')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,155):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
len(Rating),len(Review_summary),len(Full_review)
# Out:
# (1570, 1570, 1570)

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:1570], 
   'Review Summary':Review_summary[:1570], 
   'Full Review':Full_review[:1570],
   'Review_date':Date[:1570]
}
clock2 = pd.DataFrame(data=dictionnary)
pr = ['Clock']*1570

clock2.insert(0,'Product',pr)
clock2
# Out:
#      Product Rating       Review Summary  \
# 0      Clock      5  Best in the market!
# 1      Clock      5    Terrific purchase
# 2      Clock      5   Highly recommended
# 3      Clock      5       Simply awesome
# 4      Clock      4            Very Good
# ...      ...    ...                  ...
# 1565   Clock      5    Terrific purchase
# 1566   Clock      1            Worthless
# 1567   Clock      5  Best in the market!
# 1568   Clock      3       Decent product
# 1569   Clock      1            Hated it!
#
#                                             Full Review   Review_date
# 0     its really good product love it 😍😍😍😍 service a...     Dec, 2019
# 1     Wow nice watch nice looking nice colour perfec...  4 months ago
# 2     Nice item so I am very happy very fast deliver...     Mar, 2020
# 3     I liked it's shape and rich look.. little bit ...  8 months ago
# 4     Very good product. Fast delivery. Nice packing...     Jul, 2020
# ...

# %%
p = ['₹199']*1570
d = ['Kadio Analog Wall Clock']*1570

clock2.insert(1,'Price',p)
clock2.insert(1, 'Brand_name', d)
clock2
# Out:
#      Product               Brand_name Price Rating       Review Summary  \
# 0      Clock  Kadio Analog Wall Clock  ₹199      5  Best in the market!
# 1      Clock  Kadio Analog Wall Clock  ₹199      5    Terrific purchase
# 2      Clock  Kadio Analog Wall Clock  ₹199      5   Highly recommended
# 3      Clock  Kadio Analog Wall Clock  ₹199      5       Simply awesome
# 4      Clock  Kadio Analog Wall Clock  ₹199      4            Very Good
# ...      ...                      ...   ...    ...                  ...
# 1565   Clock  Kadio Analog Wall Clock  ₹199      5    Terrific purchase
# 1566   Clock  Kadio Analog Wall Clock  ₹199      1            Worthless
# 1567   Clock  Kadio Analog Wall Clock  ₹199      5  Best in the market!
# 1568   Clock  Kadio Analog Wall Clock  ₹199      3       Decent product
# 1569   Clock  Kadio Analog Wall Clock  ₹199      1            Hated it!
#
#                                             Full Review   Review_date
# ...

# %% [markdown]
# ### scrape the reviews of different brand of home theator

# %%
driver.get('https://www.flipkart.com/zebronics-bt4440-rucf-60-watt-bluetooth-home-theatre/p/itmea25dnhzbhswb?pid=ACCEA25DZGJUCYYH&lid=LSTACCEA25DZGJUCYYHQ2GZPA&marketplace=FLIPKART&q=home+theater&store=0pm%2F0o7&srno=s_1_3&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&fm=search-autosuggest&iid=02583f63-9043-41f3-b08e-57c126da7e3b.ACCEA25DZGJUCYYH.SEARCH&ppt=sp&ppn=sp&ssid=wtyugtxidc0000001659456200237&qH=6c9da984e847c7b6')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,120):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
len(Rating),len(Review_summary),len(Full_review)
# Out:
# (1200, 1200, 1200)

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:1200], 
   'Review Summary':Review_summary[:1200], 
   'Full Review':Full_review[:1200],
   'Review_date':Date[:1200]
}
Theatre1 = pd.DataFrame(data=dictionnary)
pr = ['Home Theatre']*1200

Theatre1.insert(0,'Product',pr)
Theatre1
# Out:
#            Product Rating         Review Summary  \
# 0     Home Theatre      5                Awesome
# 1     Home Theatre      5              Fabulous!
# 2     Home Theatre      5  Mind-blowing purchase
# 3     Home Theatre      4              Very Good
# 4     Home Theatre      4             Delightful
# ...            ...    ...                    ...
# 1195  Home Theatre      5      Worth every penny
# 1196  Home Theatre      5         Classy product
# 1197  Home Theatre      5              Must buy!
# 1198  Home Theatre      4             Delightful
# 1199  Home Theatre      5                 Super!
#
#                                             Full Review   Review_date
# 0     the best product in low price osm the sound qu...     Sep, 2019
# 1     Very nice quality of sound and Bass. Mere tara...     Jun, 2020
# 2     excellent product it's wark super just go this...     Jun, 2019
# 3     yes the speakers are very cool and of good qua...     May, 2020
# ...

# %%
p = ['₹2,499']*1200
d = ['ZEBRONICS BT4440 RUCF Home Theatre']*1200

Theatre1.insert(1,'Price',p)
Theatre1.insert(1, 'Brand_name',d)

Theatre1
# Out:
#            Product                          Brand_name   Price Rating  \
# 0     Home Theatre  ZEBRONICS BT4440 RUCF Home Theatre  ₹2,499      5
# 1     Home Theatre  ZEBRONICS BT4440 RUCF Home Theatre  ₹2,499      5
# 2     Home Theatre  ZEBRONICS BT4440 RUCF Home Theatre  ₹2,499      5
# 3     Home Theatre  ZEBRONICS BT4440 RUCF Home Theatre  ₹2,499      4
# 4     Home Theatre  ZEBRONICS BT4440 RUCF Home Theatre  ₹2,499      4
# ...            ...                                 ...     ...    ...
# 1195  Home Theatre  ZEBRONICS BT4440 RUCF Home Theatre  ₹2,499      5
# 1196  Home Theatre  ZEBRONICS BT4440 RUCF Home Theatre  ₹2,499      5
# 1197  Home Theatre  ZEBRONICS BT4440 RUCF Home Theatre  ₹2,499      5
# 1198  Home Theatre  ZEBRONICS BT4440 RUCF Home Theatre  ₹2,499      4
# 1199  Home Theatre  ZEBRONICS BT4440 RUCF Home Theatre  ₹2,499      5
#
#              Review Summary  \
# 0                   Awesome
# 1                 Fabulous!
# 2     Mind-blowing purchase
# ...

# %%
driver.get('https://www.flipkart.com/intex-it-2616-bt-55-w-bluetooth-home-theatre/p/itm1338b5084a829?pid=ACCFNMEYJNHSNCWN&lid=LSTACCFNMEYJNHSNCWNXWFCRW&marketplace=FLIPKART&q=home+theater&store=0pm%2F0o7&srno=s_1_2&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&fm=search-autosuggest&iid=02583f63-9043-41f3-b08e-57c126da7e3b.ACCFNMEYJNHSNCWN.SEARCH&ppt=sp&ppn=sp&ssid=wtyugtxidc0000001659456200237&qH=6c9da984e847c7b6')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,130):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
len(Rating),len(Review_summary),len(Full_review)
# Out:
# (1320, 1320, 1320)

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:1320], 
   'Review Summary':Review_summary[:1320], 
   'Full Review':Full_review[:1320],
   'Review_date':Date[:1320]
}
Theatre2 = pd.DataFrame(data=dictionnary)
pr = ['Home Theatre']*1320

Theatre2.insert(0,'Product',pr)
Theatre2
# Out:
#            Product Rating          Review Summary  \
# 0     Home Theatre      4             Good choice
# 1     Home Theatre      5               Wonderful
# 2     Home Theatre      4              Delightful
# 3     Home Theatre      5       Terrific purchase
# 4     Home Theatre      5     Best in the market!
# ...            ...    ...                     ...
# 1315  Home Theatre      5      Highly recommended
# 1316  Home Theatre      1  Worst experience ever!
# 1317  Home Theatre      1  Don't waste your money
# 1318  Home Theatre      3          Decent product
# 1319  Home Theatre      5               Must buy!
#
#                                             Full Review   Review_date
# 0     Writing this review after using 4 days.. No do...     Aug, 2020
# 1     Excellent product in budget .i m loving it.i p...     Jun, 2020
# 2     Its good in this price range but if you are lo...     Jul, 2020
# 3     Nice product. Bluetooth connectivity are very ...     Nov, 2020
# ...

# %%
p = ['₹1,699']*1320
d = ['Intex IT-2616 BT Home Theatre']*1320

Theatre2.insert(1,'Price',p)
Theatre2.insert(1, 'Brand_name', d)

Theatre2
# Out:
#            Product                     Brand_name   Price Rating  \
# 0     Home Theatre  Intex IT-2616 BT Home Theatre  ₹1,699      4
# 1     Home Theatre  Intex IT-2616 BT Home Theatre  ₹1,699      5
# 2     Home Theatre  Intex IT-2616 BT Home Theatre  ₹1,699      4
# 3     Home Theatre  Intex IT-2616 BT Home Theatre  ₹1,699      5
# 4     Home Theatre  Intex IT-2616 BT Home Theatre  ₹1,699      5
# ...            ...                            ...     ...    ...
# 1315  Home Theatre  Intex IT-2616 BT Home Theatre  ₹1,699      5
# 1316  Home Theatre  Intex IT-2616 BT Home Theatre  ₹1,699      1
# 1317  Home Theatre  Intex IT-2616 BT Home Theatre  ₹1,699      1
# 1318  Home Theatre  Intex IT-2616 BT Home Theatre  ₹1,699      3
# 1319  Home Theatre  Intex IT-2616 BT Home Theatre  ₹1,699      5
#
#               Review Summary  \
# 0                Good choice
# 1                  Wonderful
# 2                 Delightful
# 3          Terrific purchase
# 4        Best in the market!
# ...

# %%
df2
# Out:
#       Product                         Brand_name   Price Rating  \
# 0       Watch          TXOR Storm M5 Smartwatch     ₹629      5
# 1       Watch          TXOR Storm M5 Smartwatch     ₹629      5
# 2       Watch          TXOR Storm M5 Smartwatch     ₹629      5
# 3       Watch          TXOR Storm M5 Smartwatch     ₹629      5
# 4       Watch          TXOR Storm M5 Smartwatch     ₹629      5
# ..        ...                                ...     ...    ...
# 415  Iron box  Philips GC1905 Steam Iron, 1440 W  ₹1,499      5
# 416  Iron box  Philips GC1905 Steam Iron, 1440 W  ₹1,499      5
# 417  Iron box  Philips GC1905 Steam Iron, 1440 W  ₹1,499      3
# 418  Iron box  Philips GC1905 Steam Iron, 1440 W  ₹1,499      5
# 419  Iron box  Philips GC1905 Steam Iron, 1440 W  ₹1,499      3
#
#                                        Review Summary  \
# 0                                           Excellent
# 1                               Mind-blowing purchase
# ...

# %% [markdown]
# ### scrape the reviews of different brand of celing fan

# %%
driver.get('https://www.flipkart.com/bajaj-crest-neo-1200-mm-3-blade-ceiling-fan/p/itm73140916e43f1?pid=FANFVFFVNQFPFPHA&lid=LSTFANFVFFVNQFPFPHAQCNFHS&marketplace=FLIPKART&q=ceiling+fan&store=j9e%2Fabm%2Flbz&srno=s_1_3&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&fm=search-autosuggest&iid=47e75135-f95a-4155-8218-230313657cf6.FANFVFFVNQFPFPHA.SEARCH&ppt=sp&ppn=sp&ssid=cgsfdxwqhs0000001659892832672&qH=60a408f7ae06ef63')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,120):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
len(Rating),len(Review_summary),len(Full_review)
# Out:
# (1055, 1055, 1055)

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:1055], 
   'Review Summary':Review_summary[:1055], 
   'Full Review':Full_review[:1055],
   'Review_date':Date[:1055]
}
fan1 = pd.DataFrame(data=dictionnary)
pr = ['Ceiling Fan']*1055

fan1.insert(0,'Product',pr)
fan1
# Out:
#           Product Rating         Review Summary  \
# 0     Ceiling Fan      4              Wonderful
# 1     Ceiling Fan      1               Horrible
# 2     Ceiling Fan      3              Just okay
# 3     Ceiling Fan      5      Worth every penny
# 4     Ceiling Fan      5  Mind-blowing purchase
# ...           ...    ...                    ...
# 1050  Ceiling Fan      4   Good quality product
# 1051  Ceiling Fan      5              Excellent
# 1052  Ceiling Fan      1              Very poor
# 1053  Ceiling Fan      3                   Good
# 1054  Ceiling Fan      5         Simply awesome
#
#                                             Full Review    Review_date
# 0     Good quality fans. But one fan is not moving s...      Jan, 2021
# 1     Its does not gives air properly and the hanggi...  10 months ago
# 2                Soundless 👍💯\nSpeed 👎\nbuild quality 👍      Jan, 2021
# 3                                     Very nice product      Jan, 2021
# ...

# %%
p = ['₹1,299']*1055
d = ['BAJAJ Crest Neo Ceiling Fan']*1055

fan1.insert(1,'Price',p)
fan1.insert(1, 'Brand_name', d)

fan1
# Out:
#           Product                   Brand_name   Price Rating  \
# 0     Ceiling Fan  BAJAJ Crest Neo Ceiling Fan  ₹1,299      4
# 1     Ceiling Fan  BAJAJ Crest Neo Ceiling Fan  ₹1,299      1
# 2     Ceiling Fan  BAJAJ Crest Neo Ceiling Fan  ₹1,299      3
# 3     Ceiling Fan  BAJAJ Crest Neo Ceiling Fan  ₹1,299      5
# 4     Ceiling Fan  BAJAJ Crest Neo Ceiling Fan  ₹1,299      5
# ...           ...                          ...     ...    ...
# 1050  Ceiling Fan  BAJAJ Crest Neo Ceiling Fan  ₹1,299      4
# 1051  Ceiling Fan  BAJAJ Crest Neo Ceiling Fan  ₹1,299      5
# 1052  Ceiling Fan  BAJAJ Crest Neo Ceiling Fan  ₹1,299      1
# 1053  Ceiling Fan  BAJAJ Crest Neo Ceiling Fan  ₹1,299      3
# 1054  Ceiling Fan  BAJAJ Crest Neo Ceiling Fan  ₹1,299      5
#
#              Review Summary  \
# 0                 Wonderful
# 1                  Horrible
# 2                 Just okay
# 3         Worth every penny
# 4     Mind-blowing purchase
# ...                     ...
# ...

# %%
driver.get('https://www.flipkart.com/orient-electric-wendy-1200-mm-3-blade-ceiling-fan/p/itm2807ae2748b48?pid=FANESZFFYXZCBFHG&lid=LSTFANESZFFYXZCBFHGAK93IW&marketplace=FLIPKART&q=fans+ceiling+fans&store=j9e%2Fabm%2Flbz&srno=s_1_8&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&fm=search-autosuggest&iid=en_23IIBlJdLSvZ5zowzhx2iNWJiCCD5cBcHOgqm5Wul3c%2FXDcV4Hcqi4ta17tBPwcXe1uwHQh%2BkJdgwivey62acw%3D%3D&ppt=sp&ppn=sp&qH=4fabce27c368d50c')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,110):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
len(Rating),len(Review_summary),len(Full_review)
# Out:
# (1029, 1029, 1029)

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:1029], 
   'Review Summary':Review_summary[:1029], 
   'Full Review':Full_review[:1029],
   'Review_date':Date[:1029]
}
fan2= pd.DataFrame(data=dictionnary)
pr = ['Ceiling Fan']*1029

fan2.insert(0,'Product',pr)
fan2
# Out:
#           Product Rating         Review Summary  \
# 0     Ceiling Fan      5       Perfect product!
# 1     Ceiling Fan      5         Simply awesome
# 2     Ceiling Fan      5  Mind-blowing purchase
# 3     Ceiling Fan      5     Highly recommended
# 4     Ceiling Fan      5              Excellent
# ...           ...    ...                    ...
# 1024  Ceiling Fan      5                Awesome
# 1025  Ceiling Fan      5    Best in the market!
# 1026  Ceiling Fan      4   Good quality product
# 1027  Ceiling Fan      4            Good choice
# 1028  Ceiling Fan      3                   Fair
#
#                                             Full Review   Review_date
# 0     good and perfect for my home ceiling n perfect...     Jan, 2020
# 1     The packet sent by Flipkart is really good and...     Aug, 2019
# 2     Very attractive in looking, the fun runs very ...     Aug, 2020
# 3     This fan is excellent in built quality, speed,...     Aug, 2020
# ...

# %%
p = ['₹2,799']*1029
d = ['Orient Electric Wendy Ceiling Fan']*1029

fan2.insert(1,'Price',p)
fan2.insert(1, 'Brand_name', d)

fan2
# Out:
#           Product                         Brand_name   Price Rating  \
# 0     Ceiling Fan  Orient Electric Wendy Ceiling Fan  ₹2,799      5
# 1     Ceiling Fan  Orient Electric Wendy Ceiling Fan  ₹2,799      5
# 2     Ceiling Fan  Orient Electric Wendy Ceiling Fan  ₹2,799      5
# 3     Ceiling Fan  Orient Electric Wendy Ceiling Fan  ₹2,799      5
# 4     Ceiling Fan  Orient Electric Wendy Ceiling Fan  ₹2,799      5
# ...           ...                                ...     ...    ...
# 1024  Ceiling Fan  Orient Electric Wendy Ceiling Fan  ₹2,799      5
# 1025  Ceiling Fan  Orient Electric Wendy Ceiling Fan  ₹2,799      5
# 1026  Ceiling Fan  Orient Electric Wendy Ceiling Fan  ₹2,799      4
# 1027  Ceiling Fan  Orient Electric Wendy Ceiling Fan  ₹2,799      4
# 1028  Ceiling Fan  Orient Electric Wendy Ceiling Fan  ₹2,799      3
#
#              Review Summary  \
# 0          Perfect product!
# 1            Simply awesome
# 2     Mind-blowing purchase
# 3        Highly recommended
# ...

# %%
driver.get('https://www.flipkart.com/crompton-aura1-2mivory-deluxe-1200-mm-3-blade-ceiling-fan/p/itmbf7c93cc28da5?pid=FANF4DYUGU7YGGGF&lid=LSTFANF4DYUGU7YGGGFEW39Y2&marketplace=FLIPKART&q=ceiling+fan&store=j9e%2Fabm%2Flbz&spotlightTagId=BestvalueId_j9e%2Fabm%2Flbz&srno=s_2_45&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&fm=search-autosuggest&iid=5b578658-d460-4cf5-b702-630b98393b7d.FANF4DYUGU7YGGGF.SEARCH&ppt=sp&ppn=sp&qH=60a408f7ae06ef63')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,50):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:490], 
   'Review Summary':Review_summary[:490], 
   'Full Review':Full_review[:490],
   'Review_date':Date[:490]
}
fan3 = pd.DataFrame(data=dictionnary)
pr = ['Ceiling Fan']*490

fan3.insert(0,'Product',pr)
fan3
# Out:
#          Product Rating     Review Summary  \
# 0    Ceiling Fan      5  Worth every penny
# 1    Ceiling Fan      1          Hated it!
# 2    Ceiling Fan      5  Worth every penny
# 3    Ceiling Fan      4         Delightful
# 4    Ceiling Fan      5          Fabulous!
# ..           ...    ...                ...
# 485  Ceiling Fan      5     Simply awesome
# 486  Ceiling Fan      5          Brilliant
# 487  Ceiling Fan      4          Very Good
# 488  Ceiling Fan      3       Does the job
# 489  Ceiling Fan      4    Value-for-money
#
#                                            Full Review    Review_date
# 0    Order a set of 5 for our new house and they lo...      Feb, 2021
# 1    This product is not in good quality and not wo...      Apr, 2021
# 2    This is an amazing Fan, previously I had 3 Ori...  11 months ago
# 3                                                 Good      Aug, 2020
# 4                           Super quality.Nice product      Jan, 2021
# ...

# %%
p = ['₹2,799']*490
d = ['CROMPTON Aura1.2 Ceiling Fan ']*490

fan3.insert(1,'Price',p)
fan3.insert(1, 'Brand_name', d)

fan3
# Out:
#          Product                     Brand_name   Price Rating  \
# 0    Ceiling Fan  CROMPTON Aura1.2 Ceiling Fan   ₹2,799      5
# 1    Ceiling Fan  CROMPTON Aura1.2 Ceiling Fan   ₹2,799      1
# 2    Ceiling Fan  CROMPTON Aura1.2 Ceiling Fan   ₹2,799      5
# 3    Ceiling Fan  CROMPTON Aura1.2 Ceiling Fan   ₹2,799      4
# 4    Ceiling Fan  CROMPTON Aura1.2 Ceiling Fan   ₹2,799      5
# ..           ...                            ...     ...    ...
# 485  Ceiling Fan  CROMPTON Aura1.2 Ceiling Fan   ₹2,799      5
# 486  Ceiling Fan  CROMPTON Aura1.2 Ceiling Fan   ₹2,799      5
# 487  Ceiling Fan  CROMPTON Aura1.2 Ceiling Fan   ₹2,799      4
# 488  Ceiling Fan  CROMPTON Aura1.2 Ceiling Fan   ₹2,799      3
# 489  Ceiling Fan  CROMPTON Aura1.2 Ceiling Fan   ₹2,799      4
#
#         Review Summary                                        Full Review  \
# 0    Worth every penny  Order a set of 5 for our new house and they lo...
# ...

# %% [markdown]
# ### scrape the reviews of different brand of Printer

# %%
driver.get('https://www.flipkart.com/hp-deskjet-2331-multi-function-color-printer/p/itm5708dbe303a73?pid=PRNFTXAWZ9DZ2KHR&lid=LSTPRNFTXAWZ9DZ2KHRNUI3EX&marketplace=FLIPKART&q=printer&store=6bo%2Fffn%2Ft64%2Fmpr&srno=s_1_2&otracker=AS_QueryStore_OrganicAutoSuggest_2_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_2_2_na_na_na&fm=search-autosuggest&iid=26285d83-8af8-448e-b69b-b3ba510283c0.PRNFTXAWZ9DZ2KHR.SEARCH&ppt=sp&ppn=sp&ssid=8iy6qi8hz40000001659893863714&qH=a9358f4ce02708d5')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,120):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:1200], 
   'Review Summary':Review_summary[:1200], 
   'Full Review':Full_review[:1200],
   'Review_date':Date[:1200]
}
Printer1 = pd.DataFrame(data=dictionnary)
pr = ['Printer']*1200

Printer1.insert(0,'Product',pr)
Printer1
# Out:
#       Product Rating          Review Summary  \
# 0     Printer      5               Just wow!
# 1     Printer      3                    Good
# 2     Printer      5        Perfect product!
# 3     Printer      3          Decent product
# 4     Printer      1  Don't waste your money
# ...       ...    ...                     ...
# 1195  Printer      5           Great product
# 1196  Printer      1         Useless product
# 1197  Printer      1        Terrible product
# 1198  Printer      5   Mind-blowing purchase
# 1199  Printer      5                  Super!
#
#                                             Full Review Review_date
# 0     Awesome product fast printing and scanning is ...   Nov, 2020
# 1     Ink cartridge provided with it could not print...   May, 2021
# 2     Excellent .. printer Hp desk jet 2331 . And yo...   May, 2021
# 3     This product is good but the paper cost very h...   Feb, 2021
# 4     Pathetic product, worst ever printing and scan...   May, 2021
# ...

# %%
p = ['₹3,798']*1200
d = ['HP DeskJet 2331 Multi-function Color Printer']*1200

Printer1.insert(1,'Price',p)
Printer1.insert(1, 'Brand_name', d)

Printer1
# Out:
#       Product                                    Brand_name   Price Rating  \
# 0     Printer  HP DeskJet 2331 Multi-function Color Printer  ₹3,798      5
# 1     Printer  HP DeskJet 2331 Multi-function Color Printer  ₹3,798      3
# 2     Printer  HP DeskJet 2331 Multi-function Color Printer  ₹3,798      5
# 3     Printer  HP DeskJet 2331 Multi-function Color Printer  ₹3,798      3
# 4     Printer  HP DeskJet 2331 Multi-function Color Printer  ₹3,798      1
# ...       ...                                           ...     ...    ...
# 1195  Printer  HP DeskJet 2331 Multi-function Color Printer  ₹3,798      5
# 1196  Printer  HP DeskJet 2331 Multi-function Color Printer  ₹3,798      1
# 1197  Printer  HP DeskJet 2331 Multi-function Color Printer  ₹3,798      1
# 1198  Printer  HP DeskJet 2331 Multi-function Color Printer  ₹3,798      5
# 1199  Printer  HP DeskJet 2331 Multi-function Color Printer  ₹3,798      5
#
#               Review Summary  \
# 0                  Just wow!
# ...

# %%
driver.get('https://www.flipkart.com/canon-mg2570s-multi-function-color-printer/p/itme8pd6c9gcente?pid=PRNE8PD6M53KZZXA&lid=LSTPRNE8PD6M53KZZXAZEUAHX&marketplace=FLIPKART&q=printer&store=6bo%2Fffn%2Ft64%2Fmpr&srno=s_1_11&otracker=AS_QueryStore_OrganicAutoSuggest_2_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_2_2_na_na_na&fm=search-autosuggest&iid=26285d83-8af8-448e-b69b-b3ba510283c0.PRNE8PD6M53KZZXA.SEARCH&ppt=sp&ppn=sp&qH=a9358f4ce02708d5')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,90):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
len(Rating),len(Review_summary),len(Full_review)
# Out:
# (830, 830, 830)

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:830], 
   'Review Summary':Review_summary[:830], 
   'Full Review':Full_review[:830],
   'Review_date':Date[:830]
}
Printer2 = pd.DataFrame(data=dictionnary)
pr = ['Printer']*830

Printer2.insert(0,'Product',pr)
Printer2
# Out:
#      Product Rating          Review Summary  \
# 0    Printer      5        Perfect product!
# 1    Printer      5   Mind-blowing purchase
# 2    Printer      5               Excellent
# 3    Printer      5               Brilliant
# 4    Printer      1  Don't waste your money
# ..       ...    ...                     ...
# 825  Printer      1               Hated it!
# 826  Printer      1        Terrible product
# 827  Printer      4         Worth the money
# 828  Printer      4               Very Good
# 829  Printer      4             Pretty good
#
#                                            Full Review  Review_date
# 0    Very nice printer, is worth the purchase. Idea...    Jul, 2018
# 1    super Good delivery and canon printer is Good ...    May, 2019
# 2    great !! easy to use ,, budget friendly,, good...    Oct, 2019
# 3    nice product\nI am a student I ordered this fo...    May, 2020
# 4    After using 1 year I am writing\n\nProduct see...    Nov, 2017
# ...

# %%
p = ['₹3,599']*830
d = ['Canon MG2570S Printer']*830

Printer2.insert(1,'Price',p)
Printer2.insert(1, 'Brand_name', d)

Printer2
# Out:
#      Product             Brand_name   Price Rating          Review Summary  \
# 0    Printer  Canon MG2570S Printer  ₹3,599      5        Perfect product!
# 1    Printer  Canon MG2570S Printer  ₹3,599      5   Mind-blowing purchase
# 2    Printer  Canon MG2570S Printer  ₹3,599      5               Excellent
# 3    Printer  Canon MG2570S Printer  ₹3,599      5               Brilliant
# 4    Printer  Canon MG2570S Printer  ₹3,599      1  Don't waste your money
# ..       ...                    ...     ...    ...                     ...
# 825  Printer  Canon MG2570S Printer  ₹3,599      1               Hated it!
# 826  Printer  Canon MG2570S Printer  ₹3,599      1        Terrible product
# 827  Printer  Canon MG2570S Printer  ₹3,599      4         Worth the money
# 828  Printer  Canon MG2570S Printer  ₹3,599      4               Very Good
# 829  Printer  Canon MG2570S Printer  ₹3,599      4             Pretty good
#
#                                            Full Review  Review_date
# ...

# %%
driver.get('https://www.flipkart.com/canon-pixma-mg2470-all-in-one-inkjet-printer/p/itmdqatqsyzyzffn?pid=PRNDQAR9KZEKSKRF&lid=LSTPRNDQAR9KZEKSKRFYDQIJE&marketplace=FLIPKART&q=printer&store=6bo%2Fffn%2Ft64%2Fmpr&srno=s_2_48&otracker=AS_QueryStore_OrganicAutoSuggest_2_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_2_2_na_na_na&fm=search-autosuggest&iid=en_afC2%2BF24XtK1jazaoAgY5HzKWpXSW1Omg8hsGOujKDZWUH%2B1iqg%2FVLzdZ%2FAX82JrP8io9XVI%2Fwa9B7gVVMvAGQ%3D%3D&ppt=sp&ppn=sp&qH=a9358f4ce02708d5')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,50):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
len(Rating),len(Review_summary),len(Full_review)
# Out:
# (500, 500, 500)

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:500], 
   'Review Summary':Review_summary[:500], 
   'Full Review':Full_review[:500],
   'Review_date':Date[:500]
}
Printer3= pd.DataFrame(data=dictionnary)
pr = ['Printer']*500

Printer3.insert(0,'Product',pr)
Printer3
# Out:
#      Product Rating          Review Summary  \
# 0    Printer      5        Perfect product!
# 1    Printer      5   Mind-blowing purchase
# 2    Printer      5               Excellent
# 3    Printer      5               Brilliant
# 4    Printer      1  Don't waste your money
# ..       ...    ...                     ...
# 495  Printer      4         Worth the money
# 496  Printer      1  Don't waste your money
# 497  Printer      5               Just wow!
# 498  Printer      5       Terrific purchase
# 499  Printer      4               Wonderful
#
#                                            Full Review Review_date
# 0    Very nice printer, is worth the purchase. Idea...   Jul, 2018
# 1    super Good delivery and canon printer is Good ...   May, 2019
# 2    great !! easy to use ,, budget friendly,, good...   Oct, 2019
# 3    nice product\nI am a student I ordered this fo...   May, 2020
# 4    After using 1 year I am writing\n\nProduct see...   Nov, 2017
# ...

# %%
p = ['₹3,399']*500
d = ['Canon PIXMA Printer']*500

Printer3.insert(1,'Price',p)
Printer3.insert(0, 'Brand_name', d)
Printer3
# Out:
#               Brand_name  Product   Price Rating          Review Summary  \
# 0    Canon PIXMA Printer  Printer  ₹3,399      5        Perfect product!
# 1    Canon PIXMA Printer  Printer  ₹3,399      5   Mind-blowing purchase
# 2    Canon PIXMA Printer  Printer  ₹3,399      5               Excellent
# 3    Canon PIXMA Printer  Printer  ₹3,399      5               Brilliant
# 4    Canon PIXMA Printer  Printer  ₹3,399      1  Don't waste your money
# ..                   ...      ...     ...    ...                     ...
# 495  Canon PIXMA Printer  Printer  ₹3,399      4         Worth the money
# 496  Canon PIXMA Printer  Printer  ₹3,399      1  Don't waste your money
# 497  Canon PIXMA Printer  Printer  ₹3,399      5               Just wow!
# 498  Canon PIXMA Printer  Printer  ₹3,399      5       Terrific purchase
# 499  Canon PIXMA Printer  Printer  ₹3,399      4               Wonderful
#
#                                            Full Review Review_date
# ...

# %% [markdown]
# ### scrape the reviews of different brand of Refrigerator

# %%
driver.get('https://www.flipkart.com/haier-195-l-direct-cool-single-door-5-star-refrigerator/p/itm9101c1be29691?pid=RFRGFUT3897FHKXE&lid=LSTRFRGFUT3897FHKXEIBKJY9&marketplace=FLIPKART&q=refrigerator&store=j9e%2Fabm%2Fhzg&srno=s_1_13&otracker=AS_QueryStore_OrganicAutoSuggest_4_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_4_4_na_na_na&fm=Search&iid=795cd269-2f8d-4ba4-824f-6559c1aa0e22.RFRGFUT3897FHKXE.SEARCH&ppt=sp&ppn=sp&ssid=ce2h9qd8i80000001659961349724&qH=945c050322f005b6')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,120):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
len(Rating),len(Review_summary),len(Full_review)
# Out:
# (1268, 1268, 1268)

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:1268], 
   'Review Summary':Review_summary[:1268], 
   'Full Review':Full_review[:1268],
   'Review_date':Date[:1268]
}
fridge1 = pd.DataFrame(data=dictionnary)
pr = ['Refrigerator']*1268

fridge1.insert(0,'Product',pr)
fridge1
# Out:
#            Product Rating             Review Summary  \
# 0     Refrigerator      5                  Brilliant
# 1     Refrigerator      5                  Brilliant
# 2     Refrigerator      4               Nice product
# 3     Refrigerator      4                Good choice
# 4     Refrigerator      5      Mind-blowing purchase
# ...            ...    ...                        ...
# 1263  Refrigerator      2  Expected a better product
# 1264  Refrigerator      4            Worth the money
# 1265  Refrigerator      5             Classy product
# 1266  Refrigerator      5        Best in the market!
# 1267  Refrigerator      5         Highly recommended
#
#                                             Full Review Review_date
# 0     Actually, it was gifted to someone. So cannot ...   Jun, 2020
# 1     Thank God, Nice product and low sound compress...   Jul, 2020
# 2     Its compact for a 3 to 4 members family/bachel...   May, 2020
# ...

# %%
p = ['₹16,750']*1268
d = ['Haier 195 L Refrigerator']*1268

fridge1.insert(1,'Price',p)
fridge1.insert(1, 'Brand_name', d)
fridge1
# Out:
#            Product                Brand_name    Price Rating  \
# 0     Refrigerator  Haier 195 L Refrigerator  ₹16,750      5
# 1     Refrigerator  Haier 195 L Refrigerator  ₹16,750      5
# 2     Refrigerator  Haier 195 L Refrigerator  ₹16,750      4
# 3     Refrigerator  Haier 195 L Refrigerator  ₹16,750      4
# 4     Refrigerator  Haier 195 L Refrigerator  ₹16,750      5
# ...            ...                       ...      ...    ...
# 1263  Refrigerator  Haier 195 L Refrigerator  ₹16,750      2
# 1264  Refrigerator  Haier 195 L Refrigerator  ₹16,750      4
# 1265  Refrigerator  Haier 195 L Refrigerator  ₹16,750      5
# 1266  Refrigerator  Haier 195 L Refrigerator  ₹16,750      5
# 1267  Refrigerator  Haier 195 L Refrigerator  ₹16,750      5
#
#                  Review Summary  \
# 0                     Brilliant
# 1                     Brilliant
# 2                  Nice product
# 3                   Good choice
# 4         Mind-blowing purchase
# ...

# %%
driver.get('https://www.flipkart.com/lg-190-l-direct-cool-single-door-4-star-refrigerator/p/itm1963de6d2a382?pid=RFRF4HTMDHFYSXKN&lid=LSTRFRF4HTMDHFYSXKNR5GVC7&marketplace=FLIPKART&q=refrigerator&store=j9e%2Fabm%2Fhzg&srno=s_4_88&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&fm=search-autosuggest&iid=en_AujAZBrwfae2xGY3UfQE1qXpQ2tgnvbb1%2FZ1wOos1YiI5itpf5z7dYUL9vO1irX5JRyduH4uiCIqhwNlo4hbjA%3D%3D&ppt=sp&ppn=sp&qH=945c050322f005b6')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,120):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
len(Rating),len(Review_summary),len(Full_review)
# Out:
# (1120, 1120, 1120)

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:1120], 
   'Review Summary':Review_summary[:1120], 
   'Full Review':Full_review[:1120],
   'Review_date':Date[:1120]
}
fridge2= pd.DataFrame(data=dictionnary)
pr = ['Refrigerator']*1120

fridge2.insert(0,'Product',pr)
fridge2
# Out:
#            Product Rating     Review Summary  \
# 0     Refrigerator      5            Awesome
# 1     Refrigerator      5          Just wow!
# 2     Refrigerator      5  Terrific purchase
# 3     Refrigerator      5          Brilliant
# 4     Refrigerator      5           Terrific
# ...            ...    ...                ...
# 1115  Refrigerator      5          Brilliant
# 1116  Refrigerator      4       Nice product
# 1117  Refrigerator      4         Delightful
# 1118  Refrigerator      4          Wonderful
# 1119  Refrigerator      5  Worth every penny
#
#                                             Full Review   Review_date
# 0     verry good and verry comfortable design and st...     Oct, 2019
# 1     Best refrigerator on performance on .ice makin...     May, 2020
# 2     look like small but have more space. good ener...     Apr, 2019
# 3     Its is nice refrigerator and i definitely reco...     May, 2019
# ...

# %%
p = ['₹15,990']*1120
d = ['LG 190 L Refrigerator']*1120

fridge2.insert(1,'Price',p)
fridge2.insert(1, 'Brand_name', d)

fridge2
# Out:
#            Product             Brand_name    Price Rating     Review Summary  \
# 0     Refrigerator  LG 190 L Refrigerator  ₹15,990      5            Awesome
# 1     Refrigerator  LG 190 L Refrigerator  ₹15,990      5          Just wow!
# 2     Refrigerator  LG 190 L Refrigerator  ₹15,990      5  Terrific purchase
# 3     Refrigerator  LG 190 L Refrigerator  ₹15,990      5          Brilliant
# 4     Refrigerator  LG 190 L Refrigerator  ₹15,990      5           Terrific
# ...            ...                    ...      ...    ...                ...
# 1115  Refrigerator  LG 190 L Refrigerator  ₹15,990      5          Brilliant
# 1116  Refrigerator  LG 190 L Refrigerator  ₹15,990      4       Nice product
# 1117  Refrigerator  LG 190 L Refrigerator  ₹15,990      4         Delightful
# 1118  Refrigerator  LG 190 L Refrigerator  ₹15,990      4          Wonderful
# 1119  Refrigerator  LG 190 L Refrigerator  ₹15,990      5  Worth every penny
#
# ...

# %%
driver.get('https://www.flipkart.com/whirlpool-190-l-direct-cool-single-door-3-star-refrigerator/p/itmafa0a476dffe1?pid=RFRFZGFAHQ7VQXZF&lid=LSTRFRFZGFAHQ7VQXZFLUB4OV&marketplace=FLIPKART&q=refrigerator&store=j9e%2Fabm%2Fhzg&srno=s_3_50&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&fm=search-autosuggest&iid=1c165e6a-62e0-4482-ab17-57a6fdf609ef.RFRFZGFAHQ7VQXZF.SEARCH&ppt=sp&ppn=sp&qH=945c050322f005b6')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,110):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
len(Rating),len(Review_summary),len(Full_review)
# Out:
# (1010, 1010, 1010)

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:1010], 
   'Review Summary':Review_summary[:1010], 
   'Full Review':Full_review[:1010],
   'Review_date':Date[:1010]
}
fridge3 = pd.DataFrame(data=dictionnary)
pr = ['Refrigerator']*1010

fridge3.insert(0,'Product',pr)
fridge3
# Out:
#            Product Rating      Review Summary  \
# 0     Refrigerator      5              Super!
# 1     Refrigerator      4     Value-for-money
# 2     Refrigerator      4         Pretty good
# 3     Refrigerator      5  Highly recommended
# 4     Refrigerator      5      Simply awesome
# ...            ...    ...                 ...
# 1005  Refrigerator      4     Value-for-money
# 1006  Refrigerator      5           Wonderful
# 1007  Refrigerator      5   Terrific purchase
# 1008  Refrigerator      5          Nice one..
# 1009  Refrigerator      5  Highly recommended
#
#                                             Full Review Review_date
# 0     The product is good and I am so excited.\nThan...   Oct, 2019
# 1     Satisfied with the product for the money ..it ...   Aug, 2020
# 2     The price is decent for small family and budge...   Jan, 2020
# 3     Review after first couple days:\n\nLooks: The ...   Aug, 2019
# ...

# %%
p = ['₹13,690']*1010
d = ['Whirlpool 190 L Refrigerator']*1010

fridge3.insert(1,'Price',p)
fridge3.insert(1, 'Brand_name', d)

fridge3
# Out:
#            Product                    Brand_name    Price Rating  \
# 0     Refrigerator  Whirlpool 190 L Refrigerator  ₹13,690      5
# 1     Refrigerator  Whirlpool 190 L Refrigerator  ₹13,690      4
# 2     Refrigerator  Whirlpool 190 L Refrigerator  ₹13,690      4
# 3     Refrigerator  Whirlpool 190 L Refrigerator  ₹13,690      5
# 4     Refrigerator  Whirlpool 190 L Refrigerator  ₹13,690      5
# ...            ...                           ...      ...    ...
# 1005  Refrigerator  Whirlpool 190 L Refrigerator  ₹13,690      4
# 1006  Refrigerator  Whirlpool 190 L Refrigerator  ₹13,690      5
# 1007  Refrigerator  Whirlpool 190 L Refrigerator  ₹13,690      5
# 1008  Refrigerator  Whirlpool 190 L Refrigerator  ₹13,690      5
# 1009  Refrigerator  Whirlpool 190 L Refrigerator  ₹13,690      5
#
#           Review Summary                                        Full Review  \
# 0                 Super!  The product is good and I am so excited.\nThan...
# ...

# %% [markdown]
# ### scrape the reviews of different brand of Inverter AC

# %%
driver.get('https://www.flipkart.com/panasonic-1-ton-3-star-split-inverter-ac-wi-fi-connect-white/p/itmf0abff2f7eb15?pid=ACNGB9GHYFUMJTAJ&lid=LSTACNGB9GHYFUMJTAJ1RVQRO&marketplace=FLIPKART&q=AC&store=j9e%2Fabm%2Fc54&srno=s_1_11&otracker=search&otracker1=search&fm=search-autosuggest&iid=736007a4-e733-404a-987a-f2084233df03.ACNGB9GHYFUMJTAJ.SEARCH&ppt=sp&ppn=sp&ssid=2speq3bl1c0000001659898822121&qH=4144e097d2fa7a49')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,130):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
len(Rating),len(Review_summary),len(Full_review)
# Out:
# (1232, 1232, 1232)

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:1225], 
   'Review Summary':Review_summary[:1225], 
   'Full Review':Full_review[:1225],
   'Review_date':Date[:1225]
}
ac1 = pd.DataFrame(data=dictionnary)
pr = ['Inverter AC']*1225

ac1.insert(0,'Product',pr)
ac1
# Out:
#           Product Rating      Review Summary  \
# 0     Inverter AC      5           Just wow!
# 1     Inverter AC      5   Worth every penny
# 2     Inverter AC      4           Wonderful
# 3     Inverter AC      4           Wonderful
# 4     Inverter AC      5    Perfect product!
# ...           ...    ...                 ...
# 1220  Inverter AC      5       Great product
# 1221  Inverter AC      5      Simply awesome
# 1222  Inverter AC      5           Wonderful
# 1223  Inverter AC      5  Highly recommended
# 1224  Inverter AC      5  Highly recommended
#
#                                             Full Review Review_date
# 0     Delivery was smooth within 5 Days . The day i ...   Apr, 2021
# 1     Everything thing is excellent 2 small things c...   Apr, 2021
# 2     It is a overall a good bang for the buck , con...   Apr, 2021
# 3     I bought this ac on 6th april and it got deliv...   Apr, 2021
# 4     Delivery has been fast and prompt. Performance...   Apr, 2021
# ...

# %%
p = ['₹32,999']*1225
d = ['Panasonic 1 Ton 3 Star Split Inverter AC ']*1225

ac1.insert(1,'Price',p)
ac1.insert(1, 'Brand_name', d)

ac1
# Out:
#           Product                                 Brand_name    Price Rating  \
# 0     Inverter AC  Panasonic 1 Ton 3 Star Split Inverter AC   ₹32,999      5
# 1     Inverter AC  Panasonic 1 Ton 3 Star Split Inverter AC   ₹32,999      5
# 2     Inverter AC  Panasonic 1 Ton 3 Star Split Inverter AC   ₹32,999      4
# 3     Inverter AC  Panasonic 1 Ton 3 Star Split Inverter AC   ₹32,999      4
# 4     Inverter AC  Panasonic 1 Ton 3 Star Split Inverter AC   ₹32,999      5
# ...           ...                                        ...      ...    ...
# 1220  Inverter AC  Panasonic 1 Ton 3 Star Split Inverter AC   ₹32,999      5
# 1221  Inverter AC  Panasonic 1 Ton 3 Star Split Inverter AC   ₹32,999      5
# 1222  Inverter AC  Panasonic 1 Ton 3 Star Split Inverter AC   ₹32,999      5
# 1223  Inverter AC  Panasonic 1 Ton 3 Star Split Inverter AC   ₹32,999      5
# 1224  Inverter AC  Panasonic 1 Ton 3 Star Split Inverter AC   ₹32,999      5
#
# ...

# %%
driver.get('https://www.flipkart.com/samsung-1-ton-4-star-split-inverter-ac-white/p/itm746e3cc475b29?pid=ACNGAA4FHGYBP7VT&lid=LSTACNGAA4FHGYBP7VTDNLEAO&marketplace=FLIPKART&q=AC&store=j9e%2Fabm%2Fc54&srno=s_1_7&otracker=search&otracker1=search&fm=search-autosuggest&iid=d185c20c-6643-408e-a849-86a82933ab2e.ACNGAA4FHGYBP7VT.SEARCH&ppt=sp&ppn=sp&ssid=droas5uzts0000001659937515986&qH=4144e097d2fa7a49')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,135):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
# Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:1310], 
   'Review Summary':Review_summary[:1310], 
   'Full Review':Full_review[:1310],
   'Review_date':Date[:1310]
}
ac2= pd.DataFrame(data=dictionnary)
pr = ['Inverter AC']*1310

ac2.insert(0,'Product',pr)
ac2

# %%
p = ['₹30,990']*1310
d = ['SAMSUNG 1 Ton Inverter AC']*1310

ac2.insert(1,'Price',p)
ac2.insert(1, 'Brand_name', d)

ac2
# Out:
#           Product                 Brand_name    Price Rating  \
# 0     Inverter AC  SAMSUNG 1 Ton Inverter AC  ₹30,990      5
# 1     Inverter AC  SAMSUNG 1 Ton Inverter AC  ₹30,990      5
# 2     Inverter AC  SAMSUNG 1 Ton Inverter AC  ₹30,990      5
# 3     Inverter AC  SAMSUNG 1 Ton Inverter AC  ₹30,990      5
# 4     Inverter AC  SAMSUNG 1 Ton Inverter AC  ₹30,990      5
# ...           ...                        ...      ...    ...
# 1305  Inverter AC  SAMSUNG 1 Ton Inverter AC  ₹30,990      5
# 1306  Inverter AC  SAMSUNG 1 Ton Inverter AC  ₹30,990      5
# 1307  Inverter AC  SAMSUNG 1 Ton Inverter AC  ₹30,990      5
# 1308  Inverter AC  SAMSUNG 1 Ton Inverter AC  ₹30,990      5
# 1309  Inverter AC  SAMSUNG 1 Ton Inverter AC  ₹30,990      4
#
#                                     Review Summary  \
# 0                                Terrific purchase
# 1                               Highly recommended
# 2     V.Good Except installation charge by Samsung
# ...

# %% [markdown]
# ### scrape the reviews of different brand of Iron box

# %%
driver.get('https://www.flipkart.com/philips-gc1905-steam-iron-1440-w/p/itme9133697b3fb1?pid=IRND2UFFBEDXAFGC&lid=LSTIRND2UFFBEDXAFGCBUAZYR&marketplace=FLIPKART&q=iron+box&store=j9e%2Fabm%2Fa0u&srno=s_1_15&otracker=AS_QueryStore_OrganicAutoSuggest_2_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_2_3_na_na_na&fm=search-autosuggest&iid=0daf7cc4-7a4e-474e-8af0-415c8d510411.IRND2UFFBEDXAFGC.SEARCH&ppt=sp&ppn=sp&qH=946a177bc1a425de')
driver.find_element_by_xpath("//div[@class= '_3UAT2v _16PBlm']").click()

# %%
Rating=[]
Review_summary=[]
Full_review=[]
Date=[]

# %%
#so lets extract all the data having by using for loop
for i in range (0,45):
    for c in driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']/div[1]/div[1]"):
        Rating.append(c.text)
    for d in driver.find_elements_by_xpath("//div[@class='t-ZTKy']"):
        Full_review.append(d.text)
    for e in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        Review_summary.append(e.text)
    for f in driver.find_elements_by_xpath("//p[@class='_2sc7ZR']"):
        Date.append(f.text)
    try:
        driver.find_element_by_xpath("//a[@class='_1LKTO3'][2]").click()
    
    except:
        driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
    time.sleep(15)

# %%
len(Rating),len(Review_summary),len(Full_review)
# Out:
# (430, 430, 430)

# %%
#Store the data in a dataframe.    
dictionnary = {
   'Rating': Rating[:420], 
   'Review Summary':Review_summary[:420], 
   'Full Review':Full_review[:420],
   'Review_date':Date[:420]
}
ironbox1 = pd.DataFrame(data=dictionnary)
pr = ['Iron box']*420

ironbox1.insert(0,'Product',pr)
ironbox1
# Out:
#       Product Rating                                    Review Summary  \
# 0    Iron box      5                                         Fabulous!
# 1    Iron box      5                               Philips GC1903 Iron
# 2    Iron box      5                                 Philips good IRON
# 3    Iron box      4                                         Wonderful
# 4    Iron box      5                                     Excellent Buy
# ..        ...    ...                                               ...
# 415  Iron box      5                Amazing iron. More than satisfied.
# 416  Iron box      5                                      Good product
# 417  Iron box      3        Good Product but not sure the the validity
# 418  Iron box      5                                      Nice Product
# 419  Iron box      3  Good for dry iron, Steaming is not upto the mark
#
#                                            Full Review Review_date
# ...

# %%
p = ['₹1,499']*420
d = ['Philips GC1905 Steam Iron, 1440 W']*420

ironbox1.insert(1,'Price',p)
ironbox1.insert(1, 'Brand_name', d)

ironbox1
# Out:
#       Product                         Brand_name   Price Rating  \
# 0    Iron box  Philips GC1905 Steam Iron, 1440 W  ₹1,499      5
# 1    Iron box  Philips GC1905 Steam Iron, 1440 W  ₹1,499      5
# 2    Iron box  Philips GC1905 Steam Iron, 1440 W  ₹1,499      5
# 3    Iron box  Philips GC1905 Steam Iron, 1440 W  ₹1,499      4
# 4    Iron box  Philips GC1905 Steam Iron, 1440 W  ₹1,499      5
# ..        ...                                ...     ...    ...
# 415  Iron box  Philips GC1905 Steam Iron, 1440 W  ₹1,499      5
# 416  Iron box  Philips GC1905 Steam Iron, 1440 W  ₹1,499      5
# 417  Iron box  Philips GC1905 Steam Iron, 1440 W  ₹1,499      3
# 418  Iron box  Philips GC1905 Steam Iron, 1440 W  ₹1,499      5
# 419  Iron box  Philips GC1905 Steam Iron, 1440 W  ₹1,499      3
#
#                                        Review Summary  \
# 0                                           Fabulous!
# 1                                 Philips GC1903 Iron
# ...

# %% [markdown]
# ### Merging two csv files

# %%
# combining all the dataframes
df2 = pd.concat([Watch2,clock1,clock2,Theatre1,Theatre2,fan1,fan2,fan3,Printer1,Printer2,Printer3,fridge1,fridge2,fridge3,ac1,ac2,ironbox1], axis=0)

# %%
df2.to_csv('RATING_PRODUCT02_dt.csv')

# %%
df2
# Out:
#       Product                         Brand_name   Price Rating  \
# 0       Watch          TXOR Storm M5 Smartwatch     ₹629      5
# 1       Watch          TXOR Storm M5 Smartwatch     ₹629      5
# 2       Watch          TXOR Storm M5 Smartwatch     ₹629      5
# 3       Watch          TXOR Storm M5 Smartwatch     ₹629      5
# 4       Watch          TXOR Storm M5 Smartwatch     ₹629      5
# ..        ...                                ...     ...    ...
# 415  Iron box  Philips GC1905 Steam Iron, 1440 W  ₹1,499      5
# 416  Iron box  Philips GC1905 Steam Iron, 1440 W  ₹1,499      5
# 417  Iron box  Philips GC1905 Steam Iron, 1440 W  ₹1,499      3
# 418  Iron box  Philips GC1905 Steam Iron, 1440 W  ₹1,499      5
# 419  Iron box  Philips GC1905 Steam Iron, 1440 W  ₹1,499      3
#
#                                        Review Summary  \
# 0                                           Excellent
# 1                               Mind-blowing purchase
# ...

# %%
# importing pandas
import pandas as pd
  
# merging two csv files
df = pd.concat(
    map(pd.read_csv, ['RATING_products01_dt.csv', 'RATING_PRODUCT02_dt.csv']), ignore_index=True)
print(df)
# Out:
#        Unnamed: 0   Product                         Brand_name    Price  \
# 0               0     Phone                 SAMSUNG Galaxy F13  ₹11,999
# 1               1     Phone                 SAMSUNG Galaxy F13  ₹11,999
# 2               2     Phone                 SAMSUNG Galaxy F13  ₹11,999
# 3               3     Phone                 SAMSUNG Galaxy F13  ₹11,999
# 4               4     Phone                 SAMSUNG Galaxy F13  ₹11,999
# ...           ...       ...                                ...      ...
# 26018         415  Iron box  Philips GC1905 Steam Iron, 1440 W   ₹1,499
# 26019         416  Iron box  Philips GC1905 Steam Iron, 1440 W   ₹1,499
# 26020         417  Iron box  Philips GC1905 Steam Iron, 1440 W   ₹1,499
# 26021         418  Iron box  Philips GC1905 Steam Iron, 1440 W   ₹1,499
# 26022         419  Iron box  Philips GC1905 Steam Iron, 1440 W   ₹1,499
#
#        Rating                                    Review Summary  \
# ...

# %%
df.to_csv('Product_Rating.csv')
